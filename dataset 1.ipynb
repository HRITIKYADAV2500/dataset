# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from string import digits

# %%
df=pd.read_excel(r'E:\data science internship\Customer_retention_dataset---1-\Customer_retention_dataset\customer_retention_dataset.xlsx')

# %% [markdown]
# # understanding the data

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
#their is no nulll value in dataset

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %% [markdown]
# # 2 cleaning the data

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#cleaning the reapted data in columns
df.columns=df.columns.str.replace('\t','')
df.columns=df.columns.str.replace('?','')
df.columns=df.columns.str.replace('-','')
remove_digits=str.maketrans('','',digits)
df.columns=df.columns.str.translate(remove_digits)
df.columns=df.columns.str.strip()

# %%
df.isin(['NA','N/A','-',' ','?',' ?']).sum().any()
# Out:
# False

# %% [markdown]
# # 3 relationship analysis

# %% [markdown]
# with respect to time

# %%
fig,ax=plt.subplots(1,2,figsize=(18,9))

x=sns.countplot(df['Since How Long You are Shopping Online'],hue=df['Gender of respondent'],ax=ax[0])
y=df['Since How Long You are Shopping Online'].value_counts().plot.pie(autopct='%0.1f%%',ax=ax[1])

# %%
#the female has been shoping online from long time then male
#THE FELAME SHOPE MORE THEN 4 YEAR AND MALE SHOPE 2-3 YEARS LATERS
#their are 36.4% people who shope more then 4 years

# %%
pd.crosstab(df['Since How Long You are Shopping Online']  ,df['Gender of respondent'])
# Out:
# Gender of respondent                    Female  Male
# Since How Long You are Shopping Online
# 1-2 years                                   13     3
# 2-3 years                                   43    22
# 3-4 years                                   21    26
# Above 4 years                               72    26
# Less than 1 year                            32    11

# %%
#72+26=98 total people who shope more than 4 years
#so 26.7% female and 9.66% male shope more then 4 years

# %%
fig,ax=plt.subplots(1,2,figsize=(18,9))
sns.lineplot(df['How much time do you explore the e retail store before making a purchase decision'],df['Longer page loading time (promotion, sales period)'],ax=ax[1])
df['Which device do you use to access the online shopping'].value_counts().plot.pie(autopct='%0.1f%%',ax=ax[0])
# Out:
# <AxesSubplot:ylabel='Which device do you use to access the online shopping'>

# %%
pd.crosstab(df['How much time do you explore the e retail store before making a purchase decision']  ,df['Which device do you use to access the online shopping'])
# Out:
# Which device do you use to access the online shopping  Desktop  Laptop  \
# How much time do you explore the e retail store...
# 1-5 mins                                                     0       0
# 11-15 mins                                                   0      12
# 6-10 mins                                                   29      11
# Less than 1 min                                              0       0
# more than 15 mins                                            1      63
#
# Which device do you use to access the online shopping  Smartphone  Tablet
# How much time do you explore the e retail store...
# 1-5 mins                                                       13       1
# 11-15 mins                                                     34       0
# 6-10 mins                                                      30       1
# Less than 1 min                                                15       0
# ...

# %%
#more than 15 mins people sends their time on paytm ,and less then 1 min people sends on flipkart.com, on average people sends 11-15mins on all platforms
#we had some excited data the user that use laptop spends more then 15 mins to explore the window,the smart phone user

# %%
dict2={'Above 4 years':5,'3-4 years':4,'2-3 years':3,'Less than 1 year':1,'1-2 years':2}
df['average year of shoping']=df['Since How Long You are Shopping Online'].replace(dict2)

# %%
#for better under standing change 4-2 year in their average
sns.barplot(df['average year of shoping'],df['Which city do you shop online from'],data=df)
type(df['average year of shoping'])
# Out:
# pandas.core.series.Series

# %%
#from moradabad average people shope online from 5 years
#from  maximum sates shope online from 4 years
#the bulandshahr state start shoping 2 year earlier

# %%
plt.figure(figsize=(9,4))
sns.countplot(df['Since How Long You are Shopping Online'],hue=df['Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='Since How Long You are Shopping Online', ylabel='count'>

# %%
pd.crosstab([df['Since How Long You are Shopping Online']  ,df['Gender of respondent']],
            df["What browser do you run on your device to access the website"],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_1707a_row0_col0, #T_1707a_row9_col4 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_1707a_row0_col1, #T_1707a_row1_col0, #T_1707a_row1_col2, #T_1707a_row1_col3, #T_1707a_row1_col4, #T_1707a_row2_col1, #T_1707a_row2_col2, #T_1707a_row3_col1, #T_1707a_row4_col1, #T_1707a_row4_col2, #T_1707a_row4_col3, #T_1707a_row5_col1, #T_1707a_row5_col2, #T_1707a_row6_col1, #T_1707a_row6_col2, #T_1707a_row7_col1, #T_1707a_row7_col2, #T_1707a_row7_col3, #T_1707a_row8_col1, #T_1707a_row8_col2, #T_1707a_row9_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1707a_row0_col2 {
#   background-color: #5faf66;
#   color: #f1f1f1;
# }
# #T_1707a_row0_col3 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_1707a_row0_col4 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_1707a_row1_col1 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_1707a_row2_col0 {
#   background-color: #daec66;
#   color: #000000;
# }
# ...

# %%
#people who has been shope from above 4 years female has upperhand hand then male
#their is only a group of 3-4years people where male shope more then women
#the marjority of females and males use chrome

# %% [markdown]
# good performance

# %%
good=['Easy to use website or application',
      'Visual appealing webpage layout',
      'Wild variety of product on offer',
      'Complete, relevant description information of products',
      'Fast loading website speed of website and application',
      'Reliability of the website or application',
      'Quickness to complete purchase',
      'Availability of several payment options',
      'Speedy order delivery',
      'Privacy of customers’ information']

# %%
for i in good:
    plt.figure(figsize=(18,9))
    df[i].value_counts().plot.pie(autopct='%0.1f%%')

# %%
#IN EASY TO USE WEBSITE OF APPLICATION AMAZON.IN,FLIP.COM,PAYTM.COM,MYNTRA.COM,SNAPDEAL.COM TAKE 23.8%
#IN VISUAL APPEARING WEBPAGE LAYOUT AMAZON.IN AND FLIPKART.COM TAKE MAJORITY 32%
#IN WILD VARIETY OF PRODUCT ON OFFER  AMAZON.IN AND FLIPKART.COM TAKEN 48.3%
#IN COMPLETE RELEVANT DESCRIPTION INFORMATION OF PRODUCTS AMAZON.IN AND FLIPKART TAKEN 37.2%
#IN FAST LOADINGWEBSITE SPEED OF WEBSITE AND APPLICATION AMAZON TAKEN 19% AND AMAZON+PAYTM TAKEN 16.4%
#IN REALIBILITY OF THE WEBSITE OR APPLICATION AMAZON TAKEN 22.7%
#IN QUICKNESS TO COMPLETE PURCHASE AMAZON TAKEN 24.5%
#IN AVAILABILITY OF SEVERAL PAYMENT OPTIONS AMAZON AND FLIPKART TAKEN 24.2%
#IN SPEED ORDER DELEVERY AMAZON TAKEN 39.8%
#IN PRIVACY OF CUSTOMERS INFORMATION AMAZON TAKEN 26.4%

# %% [markdown]
# on the basis of society

# %%
so=['Empathy (readiness to assist with queries) towards the customers',
    'Being able to guarantee the privacy of the customer',
    'Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
    'Online shopping gives monetary benefit and discounts',
    'Enjoyment is derived from shopping online',
    'Shopping online is convenient and flexible',
    'Return and replacement policy of the etailer is important for purchase decision',
    'Gaining access to loyalty programs is a benefit of shopping online',
    'Displaying quality Information on the website improves satisfaction of customers',
    'User derive satisfaction while shopping on a good quality website or application',
    'Net Benefit derived from shopping online can lead to users satisfaction',
    'User satisfaction cannot exist without trust']

# %%
for i in so:
    plt.figure()
    sns.countplot(df[i],hue=df['Longer delivery period'])
    plt.xticks(rotation=45)
    plt.savefig('pic of graph')

# %%
#IN  Empathy (readiness to assist with queries) towards the customers people strongly agree with paytm and strongly disagree with  flipkart
#IN Being able to guarantee the privacy of the customer strongly agree with paytm and amazon and indifferent with flipkart
#IN Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.) strongly with flipkart and strongly disagree with snapdeal
#IN Online shopping gives monetary benefit and discounts strongly agree with paytm and strongly with fkipkart
#IN Enjoyment is derived from shopping online strongly agree with paytm and strongly with amazon
#IN Shopping online is convenient and flexible storngly agree with flipkart and disagree with paytm
#IN Return and replacement policy of the e-tailer is important for purchase decision strongly agree with snapdeal and disagree with paytm
#IN Gaining access to loyalty programs is a benefit of shopping online strongly agree with flipkart and disagree with paytm
#IN Displaying quality Information on the website improves satisfaction of customers strongly agree with flipkart and disagree with paytm
#IN User derive satisfaction while shopping on a good quality website or application strongly agree with paytm and disagree with amazon
#IN Net Benefit derived from shopping online can lead to users’ satisfaction strongly agree with snapdeal and disagree with paytm and snapdeal
#IN User satisfaction cannot exist without trust strongly agree with snapdeal and paytm and disagree with amazon

# %% [markdown]
# about payment system

# %%
dict4={'31-40 years':35,'21-30 years':25,'41-50 yaers':45,'Less than 20 years':20,'51 years and above':51}
df['Average age']=df['How old are you'].replace(dict4)

# %%
sns.barplot(df['Average age'],df['What is your preferred payment Option'],hue=df['Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='Average age', ylabel='What is your preferred payment Option'>

# %%
#most of the female use E-wallets, and most of the male use cash on delivery

# %% [markdown]
# #analaysis on the basis of gender

# %%
df['Gender of respondent'].value_counts().plot.pie(autopct='%0.1f%%')
plt.xlabel('Gender of respondent')
plt.ylabel('')
gender=df['Gender of respondent'].value_counts()
pcts=(gender/gender.sum())*100
print('the percentage of female purchase',int(pcts[0]))
print('the percentage of male purchase',int(pcts[1]))
# Out:
# the percentage of female purchase 67
# the percentage of male purchase 32

# %%
dict1={'31-40 years':35,'21-30 years':25,'41-50 yaers':45,'Less than 20 years':15,'51 years and above':51}
df['Average age']=df['How old are you'].replace(dict1)

# %%
plt.figure(figsize=(20,8))
sns.barplot(df['Which city do you shop online from'],df['Average age'],hue=df['Gender of respondent'],data=df)
# Out:
# <AxesSubplot:xlabel='Which city do you shop online from', ylabel='Average age'>

# %%
body=['Since How Long You are Shopping Online',
      'Which device do you use to access the online shopping',
      'What is the screen size of your mobile device',
      'Which city do you shop online from',
      'What is the operating system (OS) of your device',
      'What browser do you run on your device to access the website']

# %%
for i in  body:
    df[i].value_counts().plot.pie(autopct='%0.2f%%')
    plt.xlabel(i)
    plt.ylabel('')
    plt.figure(figsize=(10,6))

# %%
#female is double more then males and 54% people use smartphone in online shoping most of the people from delhi who shope online the operating system use by people is window and the browser used by people is google chrome

# %% [markdown]
# # CHECK CORRELATION

# %%
df1=df.corr()
df1
# Out:
#                                                     What is the Pin Code of where you shop online from  \
# What is the Pin Code of where you shop online from                                           1.000000
# average year of shoping                                                                      0.092980
# Average age                                                                                 -0.057852
#
#                                                     average year of shoping  \
# What is the Pin Code of where you shop online from                  0.09298
# average year of shoping                                             1.00000
# Average age                                                         0.02596
#
#                                                     Average age
# What is the Pin Code of where you shop online from    -0.057852
# average year of shoping                                0.025960
# ...

# %%
sns.heatmap(df1,annot=True)
# Out:
# <AxesSubplot:>

# %%
#the above map show that average age and what is the pin code of where you shope online from had negative correlation

# %% [markdown]
# ploting outlier

# %%
for i in df.columns:
    plt.figure(figsize=(7,4))
    sns.boxplot(df[i].value_counts())
